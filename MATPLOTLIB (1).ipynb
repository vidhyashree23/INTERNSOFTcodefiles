

# %%
# %matplotlib inline

# %%
plt.plot(np.random.normal(size =200),np.random.normal(size=200),'d')

# %%
normals = pd.Series(np.random.normal(size = 30))
normals.plot()
print(normals)
# Out:
# 0     0.496324
# 1     0.626672
# 2     0.090305
# 3    -1.090528
# 4    -1.056245
# 5     1.220626
# 6     2.096299
# 7    -0.022546
# 8    -0.358589
# 9     0.735619
# 10    0.656025
# 11    0.531165
# 12   -0.009375
# 13   -1.162119
# 14    0.711611
# 15   -3.193386
# 16    0.354468
# 17   -1.134919
# 18   -0.149191
# 19    0.195340
# 20   -0.783572
# 21   -1.238813
# 22    0.588387
# 23    0.113790
# 24    0.056089
# 25    0.617648
# 26   -0.530459
# 27    1.103088
# 28    0.696248
# 29   -1.071235
# dtype: float64

# %%
normals.cumsum().plot(grid = True)

# %%
variables = pd.DataFrame({'normals':np.random.normal(size = 30),'gamma':np.random.normal(size = 30),'beta':np.random.normal(size = 30)})
print(variables)
variables.cumsum(0).plot()
# Out:
#      normals     gamma      beta
# 0  -0.651284 -0.227214  1.500261
# 1  -0.734330 -0.069762  0.625041
# 2   0.751681 -1.219067  1.298537
# 3  -0.829107  0.766808 -0.775024
# 4  -0.704650  0.704942 -0.134020
# 5  -1.089067  0.711251 -1.442826
# 6   0.735140 -1.453506 -0.713523
# 7   0.441557  0.284461 -0.939541
# 8   0.070103  0.541609 -2.420813
# 9   0.360930  1.579217  0.891247
# 10  0.521170 -1.179429 -2.819964
# 11 -0.658853 -2.061948 -1.461162
# 12 -2.213798 -0.660110  0.902810
# 13 -0.648852 -1.685943 -0.405707
# 14  1.556048  1.456178  0.645526
# 15 -0.334845  0.828693  0.317811
# 16  1.239593  0.086736  0.727069
# 17 -0.216810  0.167316 -0.373569
# 18 -1.798526 -0.713350 -0.958256
# 19  1.091751 -0.100652 -1.480312
# 20  0.418352  1.071176  0.100439
# 21  0.640104  0.299335 -0.907421
# 22  0.065202 -0.470117 -1.013770
# 23 -2.094409 -0.779393 -1.004045
# 24  0.129133 -0.678736  1.400339
# 25 -0.762434  1.189736 -0.669225
# 26 -0.105034  0.965808 -0.384288
# 27  0.166600  0.660531  1.948774
# 28  0.303406 -1.425558 -1.383195
# 29 -0.780872  0.467383 -1.512088

# %%
variables.cumsum(0).plot(subplots= True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa753bcef60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa753c57550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa753b5fdd8>],
#       dtype=object)

# %%
variables.cumsum(0).plot(secondary_y = "normal")

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 12))
for i,var in enumerate(['normals','gamma','beta']):
    variables[var].cumsum(0).plot(ax=axes[i], title=var)
axes[0].set_ylabel('cumulative sum')
# Out:
# Text(0, 0.5, 'cumulative sum')

# %%
fig.savefig("figure.png")

# %%
# !ls -lh figure.png
# Out:
# -rw-r--r-- 1 root root 42K Jun 25 07:44 figure.png

# %%
from IPython.display import Image
Image("figure.png")

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpeg': 'Joint Photographic Experts Group',
#  'jpg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig = plt.figure()
ax = plt.axes()

s = np.linspace(0,20,100)
print(s)
ax.plot(s,np.sin(s));
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
#  15.75757576 15.95959596 16.16161616 16.36363636 16.56565657 16.76767677
#  16.96969697 17.17171717 17.37373737 17.57575758 17.77777778 17.97979798
#  18.18181818 18.38383838 18.58585859 18.78787879 18.98989899 19.19191919
#  19.39393939 19.5959596  19.7979798  20.        ]

# %%
plt.plot(s,np.sin(s))

# %%
plt.plot(s,np.sin(s-0),color = 'red')
plt.plot(s,np.sin(s -1),color ="y")
plt.plot(s,np.sin(s -2),color ="0.55")

# %%
plt.plot(s,np.sin(s-0),linestyle = '-')
plt.plot(s,np.sin(s -2),linestyle =":")
plt.plot(s,np.sin(s -3),linestyle ="-.")

# %%
plt.plot(s,np.sin(s-0))

plt.xlim(-1,15)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
plt.plot(s,np.cos(s))
plt.title("Cosine Curve")
plt.xlabel("x-axis")
plt.ylabel("cos(x)")
# Out:
# Text(0, 0.5, 'cos(x)')

# %%
plt.style.use("seaborn-whitegrid")

# %%
x = np.linspace(1,10,50)
y = np.log(x)

plt.plot(x,y,"o",color="green")

# %%
plt.plot(x,y,"-or")

# %%
plt.scatter(x,y,marker ="o")

# %%
rng = np.random.RandomState(7)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5,
            cmap='Reds')
plt.colorbar()

# %%
x = np.linspace(0,10,100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x,y,yerr = dy,fmt ='.b')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x = np.linspace(0,10,100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x,y,xerr = dy,fmt ='.b')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.style.use('seaborn-white')
data =np.random.randn(100000)
print(data)
# Out:
# [-2.07486566  1.01425964 -0.13898227 ... -2.06831935 -0.14094966
#  -0.72468955]

# %%
plt.hist(data)
# Out:
# (array([7.8000e+01, 9.4800e+02, 6.8650e+03, 2.1982e+04, 3.3824e+04,
#         2.5278e+04, 9.2350e+03, 1.6500e+03, 1.3200e+02, 8.0000e+00]),
#  array([-4.06036081, -3.17876641, -2.29717201, -1.41557761, -0.53398321,
#          0.34761118,  1.22920558,  2.11079998,  2.99239438,  3.87398877,
#          4.75558317]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data,bins = 30,  density=True ,alpha = 0.6,histtype='stepfilled');

# %%
x = np.random.normal(0,0.8,1000)
y = np.random.normal(-2,1,1000)

kwargs = dict(bins =60, density=True ,alpha = 0.6,histtype='stepfilled')
plt.hist(x,**kwargs)
plt.hist(y,**kwargs)
# Out:
# (array([0.00809703, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.00809703, 0.        , 0.00809703, 0.        ,
#         0.00809703, 0.        , 0.00809703, 0.02429109, 0.01619406,
#         0.03238812, 0.03238812, 0.07287327, 0.12955249, 0.09716436,
#         0.08906733, 0.0809703 , 0.13764952, 0.14574655, 0.20242576,
#         0.16194061, 0.20242576, 0.25910497, 0.33197825, 0.28339606,
#         0.36436637, 0.31578419, 0.38056043, 0.51820994, 0.44533667,
#         0.38865746, 0.33197825, 0.38056043, 0.29149309, 0.33197825,
#         0.34817231, 0.267202  , 0.28339606, 0.30768715, 0.1862317 ,
#         0.19432873, 0.09716436, 0.07287327, 0.04858218, 0.06477624,
#         0.06477624, 0.03238812, 0.01619406, 0.        , 0.00809703,
#         0.        , 0.        , 0.00809703, 0.        , 0.00809703]),
#  array([-6.1671791 , -6.04367703, -5.92017496, -5.79667289, -5.67317082,
#         -5.54966876, -5.42616669, -5.30266462, -5.17916255, -5.05566048,
#         -4.93215841, -4.80865635, -4.68515428, -4.56165221, -4.43815014,
#         -4.31464807, -4.191146  , -4.06764394, -3.94414187, -3.8206398 ,
#         -3.69713773, -3.57363566, -3.45013359, -3.32663153, -3.20312946,
#         -3.07962739, -2.95612532, -2.83262325, -2.70912119, -2.58561912,
#         -2.46211705, -2.33861498, -2.21511291, -2.09161084, -1.96810878,
#         -1.84460671, -1.72110464, -1.59760257, -1.4741005 , -1.35059843,
#         -1.22709637, -1.1035943 , -0.98009223, -0.85659016, -0.73308809,
#         -0.60958602, -0.48608396, -0.36258189, -0.23907982, -0.11557775,
#          0.00792432,  0.13142638,  0.25492845,  0.37843052,  0.50193259,
#          0.62543466,  0.74893673,  0.87243879,  0.99594086,  1.11944293,
#          1.242945  ]),
#  <a list of 1 Patch objects>)

# %%
count,bin_edges = np.histogram(data,bins =6)
print(count)
# Out:
# [  231  8812 46094 39381  5375   107]

# %%
mean =[5,2]
cov =[[3,1],[2,0.5]]
x,y = np.random.multivariate_normal(mean,cov,10000).T
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: covariance is not positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.hist2d(x,y,bins=20,cmap ='Reds')
cb = plt.colorbar()

# %%
plt.hexbin(x,y,gridsize=20,cmap ='Reds')
cb = plt.colorbar()
